# %%
#!pip install tensorflow-gpu==2.0.0-alpha0
import collections
import pandas as pd
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
pd.set_option('display.max_columns', 500)

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
df_0 = pd.read_csv("datasets/full_data/data_90644_1561101188.22012_thomas.csv")
df_1 = pd.read_csv("datasets/full_data/data_90600_1562039621.778815_jose.csv")
df_2 = pd.read_csv("datasets/full_data/data_90457_1562039922.327703_thomas.csv")
df_3 = pd.read_csv("datasets/full_data/data_90619_1562889372.0289652_jose.csv")

# %%
df = df_1

# %%
df.head()
# Out:
#    Leap timestamp  timestamp diff  emg timestamp   ch1   ch2   ch3    ch4  \
# 0    1.561949e+09        0.000523   1.561949e+09  36.0  31.0  82.0  189.0
# 1    1.561949e+09       -0.006687   1.561949e+09  29.0  33.0  92.0  182.0
# 2    1.561949e+09       -0.007372   1.561949e+09  28.0  34.0  92.0  183.0
# 3    1.561949e+09       -0.011658   1.561949e+09  26.0  32.0  84.0  197.0
# 4    1.561949e+09       -0.017067   1.561949e+09  23.0  35.0  76.0  166.0
#
#      ch5   ch6   ch7   ch8    Wrist x    Wrist y    Wrist z  Thumb Proximal x  \
# 0  221.0  64.0  36.0  24.0  19.254745  -7.083267  47.999729         -6.754491
# 1  183.0  63.0  30.0  22.0  19.278690  -7.424362  47.938534         -6.677755
# 2  189.0  70.0  27.0  23.0  19.233823  -7.826614  47.892164         -6.688048
# 3  204.0  63.0  25.0  24.0  19.119598  -8.646645  47.796652         -6.740765
# 4  237.0  63.0  27.0  24.0  19.131026 -10.078453  47.508099         -6.635715
#
#    Thumb Proximal y  Thumb Proximal z  Thumb Intermediate x  \
# 0        -18.377975         55.264462            -42.492085
# 1        -18.908295         55.094631            -42.550648
# 2        -19.483185         54.892000            -42.680784
# 3        -20.629593         54.464796            -42.941639
# 4        -22.493679         53.730776            -43.270866
#
#    Thumb Intermediate y  Thumb Intermediate z  Thumb Distal x  Thumb Distal y  \
# 0             -1.448532             28.713535      -64.697784        9.006287
# 1             -1.907715             28.772594      -64.732491        8.581528
# 2             -2.522942             28.707994      -64.856823        7.941765
# 3             -3.934959             28.397390      -65.196266        6.406059
# 4             -5.875023             28.229748      -65.772991        4.527870
#
#    Thumb Distal z  Thumb Tip x  Thumb Tip y  Thumb Tip z  Index Proximal x  \
# 0        7.357983   -83.420654    17.950516    -0.897770        -28.724483
# 1        7.409130   -83.352539    17.428741    -1.177094        -28.753090
# 2        7.326483   -83.350082    16.643997    -1.671040        -28.754079
# 3        7.037424   -83.566353    14.824036    -2.468571        -28.744416
# 4        7.161472   -84.007061    12.704842    -2.804026        -28.780963
#
#    Index Proximal y  Index Proximal z  Index Intermediate x  \
# 0          6.754868        -16.532642            -46.558819
# 1          6.766617        -16.478012            -46.479431
# 2          6.817642        -16.455212            -46.192852
# 3          6.937370        -16.422003            -45.857294
# 4          7.240463        -16.225253            -45.782590
#
#    Index Intermediate y  Index Intermediate z  Index Distal x  Index Distal y  \
# 0              5.464905            -53.422062      -55.514824       -2.848160
# 1              4.398102            -53.366005      -55.093849       -5.034119
# 2              2.852676            -53.339985      -54.152866       -8.405640
# 3              1.322083            -53.246412      -52.867331      -12.062973
# 4              0.577114            -52.927758      -51.707161      -14.727112
#
#    Index Distal z  Index Tip x  Index Tip y  Index Tip z  Middle Proximal x  \
# 0      -72.982224   -60.757153   -12.448624   -85.070961          -8.260661
# 1      -72.568657   -59.897602   -15.527969   -84.083511          -8.300241
# 2      -71.815048   -58.147932   -20.324440   -82.173851          -8.304573
# 3      -70.660912   -55.690491   -25.537895   -79.372555          -8.299355
# 4      -69.118902   -53.142047   -29.453182   -75.925150          -8.355960
#
#    Middle Proximal y  Middle Proximal z  Middle Intermediate x  \
# 0           9.196213         -21.133453             -20.106548
# 1           9.347107         -21.051586             -20.101967
# 2           9.523979         -20.970245             -20.014492
# 3           9.882469         -20.805719             -19.800578
# 4          10.501915         -20.475556             -19.625636
#
#    Middle Intermediate y  Middle Intermediate z  Middle Distal x  \
# 0              -2.366348             -64.043922       -26.854961
# 1              -1.939850             -64.047523       -26.716724
# 2              -1.549004             -64.046661       -26.448509
# 3              -0.453697             -64.120316       -25.936507
# 4               1.600239             -64.164902       -25.414562
#
#    Middle Distal y  Middle Distal z  Middle Tip x  Middle Tip y  Middle Tip z  \
# 0       -22.279465       -81.195511    -30.292061    -39.134727    -86.256828
# 1       -22.018494       -81.057610    -29.985928    -38.990707    -85.831177
# 2       -21.987556       -80.692760    -29.487785    -39.154922    -84.879845
# 3       -21.165985       -80.539688    -28.642369    -38.517242    -84.162766
# 4       -19.244289       -80.542690    -27.725950    -36.749947    -83.656700
#
#    Ring Proximal x  Ring Proximal y  Ring Proximal z  Ring Intermediate x  \
# 0        13.442685         8.256882       -20.210529             5.975285
# 1        13.407161         8.503128       -20.131874             5.938805
# 2        13.404512         8.756195       -20.024494             5.954640
# 3        13.411261         9.253754       -19.794786             6.112380
# 4        13.357842        10.022156       -19.452024             6.237359
#
#    Ring Intermediate y  Ring Intermediate z  Ring Distal x  Ring Distal y  \
# 0            -2.647095           -60.743553      -0.312822     -22.085938
# 1            -2.009598           -60.767952      -0.290539     -21.503021
# 2            -1.364647           -60.762980      -0.219350     -21.023598
# 3            -0.139420           -60.734102       0.104082     -19.945686
# 4             2.050045           -60.719983       0.420810     -17.699322
#
#    Ring Distal z  Ring Tip x  Ring Tip y  Ring Tip z  Pinky Proximal x  \
# 0     -77.515656   -4.489692  -38.735649  -82.330849         33.041229
# 1     -77.498589   -4.372024  -38.226418  -82.136986         33.030666
# 2     -77.319359   -4.195115  -37.869453  -81.589874         33.045462
# 3     -77.175587   -3.676206  -36.931572  -81.052345         33.082577
# 4     -77.298201   -3.133723  -34.787140  -80.931496         33.069088
#
#    Pinky Proximal y  Pinky Proximal z  Pinky Intermediate x  \
# 0          2.893951        -18.071293             32.986454
# 1          3.214752        -18.036346             33.068436
# 2          3.524376        -17.950647             33.251060
# 3          4.124352        -17.753216             33.586557
# 4          4.993080        -17.552148             33.969378
#
#    Pinky Intermediate y  Pinky Intermediate z  Pinky Distal x  Pinky Distal y  \
# 0             -2.544830            -51.369648       29.539677      -13.275543
# 1             -1.823318            -51.397701       29.683731      -12.435394
# 2             -1.046227            -51.377958       29.943436      -11.533310
# 3              0.382317            -51.280146       30.428234       -9.861191
# 4              2.677761            -51.195579       30.978073       -7.132244
#
#    Pinky Distal z  Pinky Tip x  Pinky Tip y  Pinky Tip z
# 0      -66.245026    24.725185   -26.346924   -74.989952
# 1      -66.372131    24.926193   -25.472214   -75.199409
# 2      -66.457050    25.238750   -24.542343   -75.353252
# 3      -66.557369    25.832626   -22.797211   -75.615574
# 4      -66.786613    26.485054   -19.928085   -76.091616

# %%
df = df.drop(labels=["Leap timestamp", "timestamp diff", "emg timestamp"], axis=1)

# %%
df.head()
# Out:
#     ch1   ch2   ch3    ch4    ch5   ch6   ch7   ch8    Wrist x    Wrist y  \
# 0  36.0  31.0  82.0  189.0  221.0  64.0  36.0  24.0  19.254745  -7.083267
# 1  29.0  33.0  92.0  182.0  183.0  63.0  30.0  22.0  19.278690  -7.424362
# 2  28.0  34.0  92.0  183.0  189.0  70.0  27.0  23.0  19.233823  -7.826614
# 3  26.0  32.0  84.0  197.0  204.0  63.0  25.0  24.0  19.119598  -8.646645
# 4  23.0  35.0  76.0  166.0  237.0  63.0  27.0  24.0  19.131026 -10.078453
#
#      Wrist z  Thumb Proximal x  Thumb Proximal y  Thumb Proximal z  \
# 0  47.999729         -6.754491        -18.377975         55.264462
# 1  47.938534         -6.677755        -18.908295         55.094631
# 2  47.892164         -6.688048        -19.483185         54.892000
# 3  47.796652         -6.740765        -20.629593         54.464796
# 4  47.508099         -6.635715        -22.493679         53.730776
#
#    Thumb Intermediate x  Thumb Intermediate y  Thumb Intermediate z  \
# 0            -42.492085             -1.448532             28.713535
# 1            -42.550648             -1.907715             28.772594
# 2            -42.680784             -2.522942             28.707994
# 3            -42.941639             -3.934959             28.397390
# 4            -43.270866             -5.875023             28.229748
#
#    Thumb Distal x  Thumb Distal y  Thumb Distal z  Thumb Tip x  Thumb Tip y  \
# 0      -64.697784        9.006287        7.357983   -83.420654    17.950516
# 1      -64.732491        8.581528        7.409130   -83.352539    17.428741
# 2      -64.856823        7.941765        7.326483   -83.350082    16.643997
# 3      -65.196266        6.406059        7.037424   -83.566353    14.824036
# 4      -65.772991        4.527870        7.161472   -84.007061    12.704842
#
#    Thumb Tip z  Index Proximal x  Index Proximal y  Index Proximal z  \
# 0    -0.897770        -28.724483          6.754868        -16.532642
# 1    -1.177094        -28.753090          6.766617        -16.478012
# 2    -1.671040        -28.754079          6.817642        -16.455212
# 3    -2.468571        -28.744416          6.937370        -16.422003
# 4    -2.804026        -28.780963          7.240463        -16.225253
#
#    Index Intermediate x  Index Intermediate y  Index Intermediate z  \
# 0            -46.558819              5.464905            -53.422062
# 1            -46.479431              4.398102            -53.366005
# 2            -46.192852              2.852676            -53.339985
# 3            -45.857294              1.322083            -53.246412
# 4            -45.782590              0.577114            -52.927758
#
#    Index Distal x  Index Distal y  Index Distal z  Index Tip x  Index Tip y  \
# 0      -55.514824       -2.848160      -72.982224   -60.757153   -12.448624
# 1      -55.093849       -5.034119      -72.568657   -59.897602   -15.527969
# 2      -54.152866       -8.405640      -71.815048   -58.147932   -20.324440
# 3      -52.867331      -12.062973      -70.660912   -55.690491   -25.537895
# 4      -51.707161      -14.727112      -69.118902   -53.142047   -29.453182
#
#    Index Tip z  Middle Proximal x  Middle Proximal y  Middle Proximal z  \
# 0   -85.070961          -8.260661           9.196213         -21.133453
# 1   -84.083511          -8.300241           9.347107         -21.051586
# 2   -82.173851          -8.304573           9.523979         -20.970245
# 3   -79.372555          -8.299355           9.882469         -20.805719
# 4   -75.925150          -8.355960          10.501915         -20.475556
#
#    Middle Intermediate x  Middle Intermediate y  Middle Intermediate z  \
# 0             -20.106548              -2.366348             -64.043922
# 1             -20.101967              -1.939850             -64.047523
# 2             -20.014492              -1.549004             -64.046661
# 3             -19.800578              -0.453697             -64.120316
# 4             -19.625636               1.600239             -64.164902
#
#    Middle Distal x  Middle Distal y  Middle Distal z  Middle Tip x  \
# 0       -26.854961       -22.279465       -81.195511    -30.292061
# 1       -26.716724       -22.018494       -81.057610    -29.985928
# 2       -26.448509       -21.987556       -80.692760    -29.487785
# 3       -25.936507       -21.165985       -80.539688    -28.642369
# 4       -25.414562       -19.244289       -80.542690    -27.725950
#
#    Middle Tip y  Middle Tip z  Ring Proximal x  Ring Proximal y  \
# 0    -39.134727    -86.256828        13.442685         8.256882
# 1    -38.990707    -85.831177        13.407161         8.503128
# 2    -39.154922    -84.879845        13.404512         8.756195
# 3    -38.517242    -84.162766        13.411261         9.253754
# 4    -36.749947    -83.656700        13.357842        10.022156
#
#    Ring Proximal z  Ring Intermediate x  Ring Intermediate y  \
# 0       -20.210529             5.975285            -2.647095
# 1       -20.131874             5.938805            -2.009598
# 2       -20.024494             5.954640            -1.364647
# 3       -19.794786             6.112380            -0.139420
# 4       -19.452024             6.237359             2.050045
#
#    Ring Intermediate z  Ring Distal x  Ring Distal y  Ring Distal z  \
# 0           -60.743553      -0.312822     -22.085938     -77.515656
# 1           -60.767952      -0.290539     -21.503021     -77.498589
# 2           -60.762980      -0.219350     -21.023598     -77.319359
# 3           -60.734102       0.104082     -19.945686     -77.175587
# 4           -60.719983       0.420810     -17.699322     -77.298201
#
#    Ring Tip x  Ring Tip y  Ring Tip z  Pinky Proximal x  Pinky Proximal y  \
# 0   -4.489692  -38.735649  -82.330849         33.041229          2.893951
# 1   -4.372024  -38.226418  -82.136986         33.030666          3.214752
# 2   -4.195115  -37.869453  -81.589874         33.045462          3.524376
# 3   -3.676206  -36.931572  -81.052345         33.082577          4.124352
# 4   -3.133723  -34.787140  -80.931496         33.069088          4.993080
#
#    Pinky Proximal z  Pinky Intermediate x  Pinky Intermediate y  \
# 0        -18.071293             32.986454             -2.544830
# 1        -18.036346             33.068436             -1.823318
# 2        -17.950647             33.251060             -1.046227
# 3        -17.753216             33.586557              0.382317
# 4        -17.552148             33.969378              2.677761
#
#    Pinky Intermediate z  Pinky Distal x  Pinky Distal y  Pinky Distal z  \
# 0            -51.369648       29.539677      -13.275543      -66.245026
# 1            -51.397701       29.683731      -12.435394      -66.372131
# 2            -51.377958       29.943436      -11.533310      -66.457050
# 3            -51.280146       30.428234       -9.861191      -66.557369
# 4            -51.195579       30.978073       -7.132244      -66.786613
#
#    Pinky Tip x  Pinky Tip y  Pinky Tip z
# 0    24.725185   -26.346924   -74.989952
# 1    24.926193   -25.472214   -75.199409
# 2    25.238750   -24.542343   -75.353252
# 3    25.832626   -22.797211   -75.615574
# 4    26.485054   -19.928085   -76.091616

# %%
df.describe()
# Out:
#                 ch1           ch2           ch3           ch4           ch5  \
# count  90600.000000  90600.000000  90600.000000  90600.000000  90600.000000
# mean      44.583863     49.292219    123.360077    348.453002    332.704073
# std       54.203637     29.438165     86.410152    197.000835    157.950882
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       26.000000     34.000000     69.000000    197.000000    236.000000
# 50%       31.000000     41.000000    101.000000    313.000000    316.000000
# 75%       42.000000     53.000000    148.000000    470.000000    405.000000
# max      970.000000    755.000000   1070.000000   1407.000000   1330.000000
#
#                 ch6           ch7           ch8       Wrist x       Wrist y  \
# count  90600.000000  90600.000000  90600.000000  90600.000000  90600.000000
# mean     104.559393     78.189007     69.638433     21.681959    -15.068355
# std       83.527089    127.436655    121.686572      9.825154     13.320584
# min        0.000000      0.000000      0.000000    -29.343874    -52.549845
# 25%       58.000000     26.000000     23.000000     17.978174    -24.354976
# 50%       79.000000     36.000000     28.000000     23.275366    -16.041552
# 75%      121.000000     66.000000     54.000000     27.772394     -6.808727
# max     1343.000000   1336.000000   1542.000000     51.105246     49.048274
#
#             Wrist z  Thumb Proximal x  Thumb Proximal y  Thumb Proximal z  \
# count  90600.000000      90600.000000      90600.000000      90600.000000
# mean      40.502341         -1.203590        -29.225487         45.406689
# std        6.892197         11.623648         14.633970          9.381554
# min      -32.522915        -53.974251        -58.849787        -30.463521
# 25%       36.789361         -6.907897        -39.748237         39.834438
# 50%       41.693902         -0.067610        -31.412725         46.920048
# 75%       45.367455          6.306405        -20.658276         52.710029
# max       54.052528         53.248611         54.161324         61.022614
#
#        Thumb Intermediate x  Thumb Intermediate y  Thumb Intermediate z  \
# count          90600.000000          90600.000000          90600.000000
# mean             -32.484780            -31.542150             15.275545
# std               10.815085             12.488255             11.583462
# min              -73.549263            -56.236760            -43.421036
# 25%              -40.010123            -40.356688              8.977968
# 50%              -33.305660            -33.824551             16.371096
# 75%              -25.966050            -25.385868             22.854068
# max               36.943094             61.088989             56.262566
#
#        Thumb Distal x  Thumb Distal y  Thumb Distal z   Thumb Tip x  \
# count    90600.000000    90600.000000    90600.000000  90600.000000
# mean       -51.110008      -32.822997       -6.597438    -63.337830
# std         16.760959       16.721658       16.831132     24.585213
# min        -94.561996      -69.227956      -71.112949   -113.950043
# 25%        -63.409739      -44.460924      -17.241336    -82.334449
# 50%        -54.136506      -35.712880       -5.605721    -69.887058
# 75%        -40.647496      -24.222244        4.702193    -46.076807
# max         34.616081       67.583832       70.703629     36.394524
#
#         Thumb Tip y   Thumb Tip z  Index Proximal x  Index Proximal y  \
# count  90600.000000  90600.000000      90600.000000      90600.000000
# mean     -33.041773    -18.098342        -28.488517          6.852023
# std       21.128496     23.010135          4.679808          7.204394
# min      -85.412560    -85.743622        -34.246284        -33.360283
# 25%      -47.553139    -35.080935        -31.206747          2.289987
# 50%      -36.191029    -17.339439        -29.861434          6.870478
# 75%      -21.817017     -2.077390        -27.478947         11.523385
# max       87.214348     79.560699         18.662185         35.441299
#
#        Index Proximal z  Index Intermediate x  Index Intermediate y  \
# count      90600.000000          90600.000000          90600.000000
# mean         -12.098426            -41.434892              5.822841
# std            6.129145             11.541585             21.484541
# min          -33.916698            -69.748993            -66.736385
# 25%          -15.335609            -48.830143            -10.424944
# 50%          -11.950797            -43.184705              5.566509
# 75%           -8.162726            -36.801661             21.711502
# max           15.188611             33.403296             69.413376
#
#        Index Intermediate z  Index Distal x  Index Distal y  Index Distal z  \
# count          90600.000000    90600.000000    90600.000000    90600.000000
# mean             -45.017299      -46.017369       -0.489549      -61.341197
# std                9.583364       16.092818       31.310559       13.214738
# min              -72.006081      -89.663483      -86.346446      -94.814049
# 25%              -50.751590      -57.102228      -26.400365      -69.717551
# 50%              -45.482523      -48.068892       -1.287778      -62.695897
# 75%              -39.485516      -37.666778       23.630946      -54.468701
# max               39.432669       47.879412       92.422882       59.662006
#
#         Index Tip x   Index Tip y   Index Tip z  Middle Proximal x  \
# count  90600.000000  90600.000000  90600.000000       90600.000000
# mean     -47.922836     -6.774095    -71.020212          -9.861496
# std       19.827498     37.942652     17.760738           4.711529
# min     -103.300975   -102.515004   -110.925060         -23.881287
# 25%      -62.089896    -39.283085    -82.904263         -12.997995
# 50%      -50.399091     -8.723793    -73.963530         -10.638683
# 75%      -36.452655     22.739767    -62.165624          -7.787399
# max       58.526260    108.614807     71.227489          15.991913
#
#        Middle Proximal y  Middle Proximal z  Middle Intermediate x  \
# count       90600.000000       90600.000000           90600.000000
# mean           12.036341         -16.443250             -18.036426
# std             5.699864           4.215960              12.927463
# min           -21.616302         -25.227974             -62.910980
# 25%             8.753171         -19.597597             -25.920038
# 50%            12.727828         -17.068754             -19.688862
# 75%            16.082306         -13.794679             -12.631642
# max            24.944417          10.799900              44.770500
#
#        Middle Intermediate y  Middle Intermediate z  Middle Distal x  \
# count           90600.000000           90600.000000     90600.000000
# mean               10.970628             -54.847787       -21.638468
# std                22.992465               8.377177        17.178296
# min               -64.685115             -72.785343       -88.653748
# 25%                -7.075348             -60.370221       -31.886919
# 50%                12.231331             -56.024634       -23.544468
# 75%                28.843407             -50.633778       -14.073638
# max                69.693136              48.803154        64.165855
#
#        Middle Distal y  Middle Distal z  Middle Tip x  Middle Tip y  \
# count     90600.000000     90600.000000  90600.000000  90600.000000
# mean          3.270985       -74.139309    -23.355840     -4.000151
# std          35.248417        14.420081     19.805802     42.929131
# min         -88.274813      -100.008995   -105.281708   -103.039251
# 25%         -26.561827       -83.948338    -35.311320    -41.638851
# 50%           3.989063       -77.149472    -25.562433     -4.314671
# 75%          31.470230       -67.831231    -14.280526     30.138170
# max          94.781616        73.004902     76.842743    110.278854
#
#        Middle Tip z  Ring Proximal x  Ring Proximal y  Ring Proximal z  \
# count  90600.000000     90600.000000     90600.000000     90600.000000
# mean     -84.578372        10.566678        13.119811       -16.679150
# std       20.823931         4.545620         6.085000         4.667393
# min     -118.532631       -24.355642       -23.938806       -25.997555
# 25%      -99.426664         7.694267         9.884148       -20.042524
# 50%      -90.451378        10.463804        14.277980       -17.394681
# 75%      -74.856444        13.169882        17.531076       -14.062234
# max       86.081692        26.374695        24.688248        11.281423
#
#        Ring Intermediate x  Ring Intermediate y  Ring Intermediate z  \
# count         90600.000000         90600.000000         90600.000000
# mean              3.909116             8.546182           -52.529102
# std              12.249250            20.191252             7.980543
# min             -57.522280           -56.957550           -67.502625
# 25%              -3.374719            -6.885628           -57.583257
# 50%               3.226278             8.702098           -53.919234
# 75%               9.998981            24.046379           -49.403713
# max              58.963965            60.903819            46.899132
#
#        Ring Distal x  Ring Distal y  Ring Distal z    Ring Tip x  \
# count   90600.000000   90600.000000   90600.000000  90600.000000
# mean        0.071619      -1.626180     -70.660393     -2.162509
# std        16.397898      30.551609      14.371567     18.871552
# min       -81.246136     -82.605845     -94.302910    -95.764450
# 25%        -9.458436     -27.152271     -80.313945    -13.091498
# 50%        -0.744401      -2.748502     -74.199478     -3.193758
# 75%         7.817459      21.879673     -64.758243      6.977424
# max        80.266543      84.211563      69.468498     94.602086
#
#          Ring Tip y    Ring Tip z  Pinky Proximal x  Pinky Proximal y  \
# count  90600.000000  90600.000000      90600.000000      90600.000000
# mean     -10.723395    -80.223146         29.482285          9.810576
# std       36.920724     21.053166          4.940631          8.486368
# min      -99.340668   -112.309074        -36.867088        -37.400208
# 25%      -42.276178    -95.182503         27.209934          5.750765
# 50%      -13.637778    -86.667567         29.995578         11.357185
# 75%       17.279953    -70.251308         32.454923         15.810720
# max      100.570892     80.748665         39.266825         36.744105
#
#        Pinky Proximal z  Pinky Intermediate x  Pinky Intermediate y  \
# count      90600.000000          90600.000000          90600.000000
# mean         -16.763878             28.820737              7.584308
# std            7.008461             12.112250             17.600043
# min          -35.211014            -55.896645            -58.016373
# 25%          -21.320105             22.197178             -5.163932
# 50%          -17.773488             29.334076              8.271385
# 75%          -14.001711             35.958374             21.822002
# max           30.679637             65.666873             61.874748
#
#        Pinky Intermediate z  Pinky Distal x  Pinky Distal y  Pinky Distal z  \
# count          90600.000000    90600.000000    90600.000000    90600.000000
# mean             -45.488672       26.967847        1.531529      -58.953151
# std                9.544128       16.052064       24.209579       12.774926
# min              -63.495749      -67.025665      -70.088516      -80.489201
# 25%              -51.302513       17.639107      -17.893308      -67.135653
# 50%              -47.576801       27.371721        1.163478      -62.129180
# 75%              -42.570370       36.051557       21.398380      -54.590542
# max               41.748179       82.882950       80.013344       57.246925
#
#         Pinky Tip x   Pinky Tip y   Pinky Tip z
# count  90600.000000  90600.000000  90600.000000
# mean      24.714798     -5.878206    -68.631445
# std       19.161539     29.736909     17.776431
# min      -80.199478    -83.873207    -95.711021
# 25%       13.262431    -30.927790    -80.839409
# 50%       24.933261     -7.679316    -73.898590
# 75%       35.384776     18.147858    -60.750480
# max       97.776947     95.258278     67.835724

# %% [markdown]
# ### Autoencoder

# %%
raw_features = df.loc[:, 'ch1':'ch8'].values
raw_labels = df.loc[:, 'Wrist x':].values

# %%
raw_features.shape
# Out:
# (90619, 8)

# %%
raw_labels.shape
# Out:
# (90619, 63)

# %%
encoding_dim = 9

input_vec = Input(shape=(63,))
dense_0 = Dense(32, activation=None)(input_vec)
dense_1 = Dense(16, activation=None)(dense_0)
encoded = Dense(encoding_dim, activation=None)(dense_1)
dense_2 = Dense(32, activation=None, name='decoder_0')(encoded)
dense_3 = Dense(16, activation=None, name='decoder_1')(dense_2)
decoded = Dense(63, activation=None, name='decoder_output')(dense_3)

autoencoder = Model(input_vec, decoded)
encoder = Model(input_vec, encoded)

encoded_input = Input(shape=(encoding_dim,), name='encoded_input')
decode_0 = autoencoder.layers[-3](encoded_input)
decode_1 = autoencoder.layers[-2](decode_0)
decode_output = autoencoder.layers[-1](decode_1)
decoder = Model(encoded_input, decode_output, name='decoder')
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
autoencoder.compile(optimizer=optimizer, loss='mean_squared_error')
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 63)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2048
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_11 (Dense)             (None, 9)                 153
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 4,648
# Trainable params: 4,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 63)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2048
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_11 (Dense)             (None, 9)                 153
# =================================================================
# Total params: 2,729
# Trainable params: 2,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_input (InputLayer)   (None, 9)                 0
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 1,919
# Trainable params: 1,919
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.evaluate(raw_labels, raw_labels)
# Out:
# 90600/90600 [==============================] - 4s 44us/sample - loss: 33.3151
# 33.315060228384354

# %%
ret = autoencoder.fit(raw_labels, raw_labels, batch_size=512, epochs=5, verbose=1, validation_split=0.2)
# Out:
# Train on 72495 samples, validate on 18124 samples
# Epoch 1/5
# 72495/72495 [==============================] - 1s 12us/sample - loss: 24.6918 - val_loss: 15.4279
# Epoch 2/5
# 72495/72495 [==============================] - 1s 12us/sample - loss: 19.1857 - val_loss: 14.2306
# Epoch 3/5
# 72495/72495 [==============================] - 1s 14us/sample - loss: 17.3400 - val_loss: 13.4639
# Epoch 4/5
# 72495/72495 [==============================] - 1s 17us/sample - loss: 16.3530 - val_loss: 13.1049
# Epoch 5/5
# 72495/72495 [==============================] - 1s 16us/sample - loss: 15.8651 - val_loss: 13.0581

# %%
#evaluate autoencoder performance
encoded_vec = encoder.predict(raw_labels)
decoded_vec = decoder.predict(encoded_vec)

# %%
decoder.compile(optimizer='adam', loss='mse')
decoder.evaluate(encoded_vec, raw_labels)
# Out:
# 90619/90619 [==============================] - 3s 31us/sample - loss: 15.1807
# 15.180652346829817

# %%
encoded_vec.shape
# Out:
# (90457, 9)

# %%
decoded_vec.shape
# Out:
# (90457, 63)

# %%
# def reshape_data(seq_length, features, labels):
#     samples = features.shape[0] // seq_length
#     new_f = np.zeros((samples, seq_length, features.shape[1]))
#     new_l = np.zeros((samples, seq_length, labels.shape[1]))
#     j = 0
#     for i in range(0, features.shape[0], seq_length):
#         if (i + seq_length <= features.shape[0]):
#             new_f[j] = features[i:i + seq_length]
#             new_l[j] = labels[i:i + seq_length]
#         j += 1
#     return (new_f, new_l)

# %%
def overlap_reshape(seq_length, feats, labs):
    samples = feats.shape[0] - (seq_length - 1)
    new_f = np.zeros((samples, seq_length, feats.shape[1]))
    new_l = labs[seq_length - 1:]
    queue = collections.deque(feats[:seq_length])
    new_f[0] = np.array(queue)
    j = 1
    for i in range(seq_length, feats.shape[0]):
        queue.popleft()
        queue.append(feats[i])
        new_f[j] = np.array(queue)
        j += 1
    return (new_f, new_l)

# %% [markdown]
# ### Lotery LSTM (Autoencoder)

# %%
seq_length = 24
features, labels = overlap_reshape(seq_length, raw_features, encoded_vec)

# %%
# seq_length = 24
# features, labels = reshape_data(seq_length, raw_features, encoded_vec)

# %%
labels.shape
# Out:
# (90596, 9)

# %%
features.shape
# Out:
# (90596, 24, 8)

# %%
decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_input (InputLayer)   (None, 9)                 0
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 1,919
# Trainable params: 1,919
# Non-trainable params: 0
# _________________________________________________________________

# %%
#lstm layers
inputs = Input(shape=(None, 8), name="inputs")
lstm_0 = LSTM(64, return_sequences=True, name="lstm_0")(inputs)
lstm_1 = LSTM(64, return_sequences=False, name="lstm_1")(lstm_0)
lstm_out = Dense(9, activation=None, name="lstm_out")(lstm_1)

#decoder layers
decoder_0 = decoder.get_layer("decoder_0")(lstm_out)
decoder_0.trainable = False
decoder_1 = decoder.get_layer("decoder_1")(decoder_0)
decoder_1.trainable = False
decoder_output = decoder.get_layer("decoder_output")(decoder_1)
decoder_output.trainable = False

model = Model(inputs, decoder_output, name="model_v1")
# model = Model(inputs, dense, name="lstm_model")
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mse')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, None, 8)           0
# _________________________________________________________________
# lstm_0 (LSTM)                (None, None, 64)          18688
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# lstm_out (Dense)             (None, 9)                 585
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 54,216
# Trainable params: 54,216
# Non-trainable params: 0
# _________________________________________________________________

# %%
features.shape
# Out:
# (90596, 24, 8)

# %%
raw_labels[seq_length - 1:].shape
# Out:
# (90596, 63)

# %%
model.evaluate(features, raw_labels[seq_length - 1:], verbose=1)
# Out:
# 90577/90577 [==============================] - 41s 452us/sample - loss: 580.2550
# 580.254974971382

# %%
model.fit(features, raw_labels[seq_length - 1:], batch_size=seq_length, epochs=1, verbose=1, validation_split=0.2);
# Out:
# Train on 72476 samples, validate on 18120 samples
# 72476/72476 [==============================] - 161s 2ms/sample - loss: 243.3608 - val_loss: 265.4522

# %%
k

# %%
model.save("saved_models/model_highloss_jose_2_001.h5")

# %%
m = load_model("saved_models/model_overfitted_thomas_2_001.h5")

# %%
m.evaluate(features, raw_labels[seq_length - 1:])
# Out:
# 90434/90434 [==============================] - 34s 373us/sample - loss: 329.6422
# 329.6421536507562

# %%
preds = model.predict(features)

# %%
preds.shape

# %%
preds = preds.reshape(-1, 9)

# %%
preds.shape

# %%
raw_labels[:preds.shape[0]].shape

# %%
raw_labels[seq_length - 1:].shape

# %%
decoder.evaluate(preds, raw_labels[seq_length - 1:])

# %% [markdown]
# #### Save predictions

# %%
full_preds = decoder.predict(preds)

# %%
full_preds_df = pd.DataFrame(data=full_preds, columns=df.loc[:, 'Wrist x':].columns)

# %%
full_preds_df.to_csv("predictions/pred_001.csv", index=False)

# %% [markdown]
# ### Run a model multiple times until it hits the lottery

# %%
# %%time
eval_loss = 300
current_best = 1000
cur_model = 0

while (eval_loss > 180):
    total_epochs = 0
    inputs = Input(shape=(None, 8))
    lstm = LSTM(64, return_sequences=True)(inputs)
    lstm = LSTM(64, return_sequences=True)(lstm)
    dense = Dense(9, activation=None)(lstm)

    model = Model(inputs, dense)
    optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(optimizer=optimizer, loss='mse')

    model.evaluate(features, labels, verbose=1)

    history = model.fit(features, labels, batch_size=seq_length, epochs=1, verbose=1, validation_split=0.2)

    while (history.history['loss'][-1] - history.history['val_loss'][-1] > -100):
        history = model.fit(features, labels, batch_size=seq_length, epochs=10, verbose=1, validation_split=0.2)
        total_epochs += 10
    
    preds = model.predict(features)
    preds = preds.reshape(-1, 9)
    eval_loss = decoder.evaluate(preds, raw_labels[:preds.shape[0]])
    if (eval_loss < current_best):
        current_best = eval_loss
        model.save('saved_models/model_{}.h5'.format(round(current_best)))
    print("|||||||||||||||||||||||||||||||||||||||||||||||||")
    print("Current model ==> {}".format(cur_model))
    print("Total epochs  ==> {}".format(total_epochs))
    print("Current loss  ==> {}".format(eval_loss))
    print("Current best  ==> {}".format(current_best))
    print("|||||||||||||||||||||||||||||||||||||||||||||||||")
    cur_model += 1

# %% [markdown]
# ### Saving and loading model

# %%
from tensorflow.keras.models import load_model

model = load_model('model_200.h5')

# %%
model.save_weights('model_200_weights.h5')

# %%
model.summary()

# %%
inputs = Input(shape=(None, 8))
lstm = LSTM(256, recurrent_activation='hard_sigmoid', return_sequences=True)(inputs)
lstm = LSTM(256, recurrent_activation='hard_sigmoid', return_sequences=True)(lstm)
#lstm3 = CuDNNLSTM(256, return_sequences=True)(lstm2)
#lstm4 = CuDNNLSTM(256, return_sequences=True)(lstm3)
dense = Dense(63, activation=None)(lstm)

model = Model(inputs, dense)
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()

# %%
model.load_weights('model_200_weights.h5')

# %%
model.summary()

# %%
model.evaluate(features, labels)

# %%
model.save('model_200_v2.h5')

# %% [markdown]
# ### Lotery LSTM

# %%
inputs = Input(shape=(None, 8))
lstm = CuDNNLSTM(256, return_sequences=True)(inputs)
lstm = CuDNNLSTM(256, return_sequences=True)(lstm)
#lstm3 = CuDNNLSTM(256, return_sequences=True)(lstm2)
#lstm4 = CuDNNLSTM(256, return_sequences=True)(lstm3)
dense = Dense(63, activation=None)(lstm)

model = Model(inputs, dense)
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()

# %%
seq_length = 32

# %%
features, labels = reshape_data(seq_length, raw_features, raw_labels)

# %%
features.shape

# %%
labels.shape

# %%
model.evaluate(features, labels, verbose=1)

# %%
model.fit(features, labels, batch_size=seq_length, epochs=100, verbose=1, validation_split=0.2)

# %%
model.save("model_200.h5")

# %% [markdown]
# ### LSTM Model

# %%
seq_length = 100
features = df.loc[:, 'ch1':'ch8'].values
labels = df.loc[:, 'Wrist x':].values

# %%
features, labels = reshape_data(seq_length, features, encoded_vec)

# %%
features.shape

# %%
labels.shape

# %%
input_size = features.shape[2]
hidden_size = 256
output_size = labels.shape[2]

input_vec = Input(shape=(None, input_size))
lstm = CuDNNLSTM(hidden_size, return_sequences=True)(input_vec)
lstm = CuDNNLSTM(hidden_size, return_sequences=True)(lstm)
dense = Dense(output_size, activation=None)(lstm)

model = Model(input_vec, dense)
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()

# %%
model.fit(features, labels, batch_size=100, epochs=1000, verbose=1, validation_split=0.2)

# %% [markdown]
# ### Neural Net Model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1024, activation='relu', input_shape=(8,)))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1024, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(63, activation='relu'))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# %%
# %%time
#ret = model.fit(features, labels, epochs=3000, verbose=2)
ret = model.fit(features, labels, batch_size=256, epochs=1000, verbose=2, validation_split=0.2)
