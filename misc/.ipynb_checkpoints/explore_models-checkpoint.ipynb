# %%
#!pip install tensorflow-gpu==2.0.0-alpha0
import collections
import pandas as pd
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
pd.set_option('display.max_columns', 500)

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
df_0 = pd.read_csv("datasets/full_data/data_90644_1561101188.22012_thomas.csv")
df_1 = pd.read_csv("datasets/full_data/data_90600_1562039621.778815_jose.csv")
df_2 = pd.read_csv("datasets/full_data/data_90457_1562039922.327703_thomas.csv")
df_3 = pd.read_csv("datasets/full_data/data_90619_1562889372.0289652_jose.csv")

# %%
df = df_0

# %%
df.head()
# Out:
#    Leap timestamp  timestamp diff  emg timestamp   ch1   ch2   ch3   ch4  \
# 0    1.561069e+09        0.021962   1.561069e+09  20.0  26.0  45.0  62.0
# 1    1.561069e+09        0.006170   1.561069e+09  20.0  26.0  46.0  69.0
# 2    1.561069e+09       -0.008751   1.561069e+09  20.0  24.0  39.0  67.0
# 3    1.561069e+09       -0.008863   1.561069e+09  21.0  24.0  38.0  69.0
# 4    1.561069e+09       -0.012413   1.561069e+09  21.0  24.0  36.0  69.0
#
#      ch5   ch6   ch7   ch8    Wrist x    Wrist y    Wrist z  Thumb Proximal x  \
# 0  270.0  38.0  23.0  24.0  44.092537 -11.826508  15.329117         32.816284
# 1  274.0  37.0  24.0  24.0  44.033386 -11.873871  15.461998         32.681427
# 2  275.0  36.0  20.0  23.0  43.889786 -12.179611  15.631538         32.381157
# 3  298.0  43.0  20.0  24.0  43.316656 -13.989517  15.712471         31.439707
# 4  261.0  38.0  19.0  23.0  42.605598 -15.925362  15.807536         30.223984
#
#    Thumb Proximal y  Thumb Proximal z  Thumb Intermediate x  \
# 0        -17.849213         39.115044             -7.700520
# 1        -17.868637         39.218956             -7.868088
# 2        -18.243423         39.295410             -8.186592
# 3        -19.986164         39.210838             -8.706076
# 4        -22.206261         38.968119             -9.576688
#
#    Thumb Intermediate y  Thumb Intermediate z  Thumb Distal x  Thumb Distal y  \
# 0             -4.460510             49.599419      -35.444817        4.608963
# 1             -4.452667             49.540733      -35.642456        4.626099
# 2             -4.713959             49.395020      -35.978706        4.436554
# 3             -5.141907             49.146923      -36.223530        4.900223
# 4             -6.248133             48.554169      -36.892214        4.531774
#
#    Thumb Distal z  Thumb Tip x  Thumb Tip y  Thumb Tip z  Index Proximal x  \
# 0       56.584419   -54.457291    10.868591    61.458855        -27.160671
# 1       56.392906   -54.687771    10.879211    61.146019        -27.173590
# 2       56.077698   -55.039932    10.734818    60.705765        -27.164951
# 3       55.683292   -55.089439    11.816055    60.228619        -26.780442
# 4       54.749029   -55.574656    11.993368    59.184738        -26.456961
#
#    Index Proximal y  Index Proximal z  Index Intermediate x  \
# 0         11.812378          9.818542            -58.868332
# 1         11.852524          9.734039            -58.838871
# 2         11.938171          9.653145            -58.705818
# 3         12.766251          9.667107            -57.800222
# 4         13.383306          9.721865            -56.977891
#
#    Index Intermediate y  Index Intermediate z  Index Distal x  Index Distal y  \
# 0             24.661255             -6.298439      -77.143066       16.417236
# 1             24.680725             -6.482422      -77.092003       16.421097
# 2             24.955734             -6.654617      -76.953636       16.796005
# 3             27.029053             -6.597591      -76.276329       19.596748
# 4             28.848368             -6.386009      -75.606583       22.222661
#
#    Index Distal z  Index Tip x  Index Tip y  Index Tip z  Middle Proximal x  \
# 0      -13.422653   -84.756599     3.553970   -15.086433         -18.418987
# 1      -13.643852   -84.698669     3.554321   -15.311935         -18.383682
# 2      -13.942993   -84.603577     3.968384   -15.711678         -18.288635
# 3      -14.085293   -84.368996     7.078911   -16.085609         -17.835115
# 4      -14.241512   -84.150408    10.099126   -16.726961         -17.330064
#
#    Middle Proximal y  Middle Proximal z  Middle Intermediate x  \
# 0          10.669708          -7.552521             -50.664906
# 1          10.688812          -7.611267             -50.551685
# 2          10.822479          -7.651268             -50.286522
# 3          11.589149          -7.597649             -49.262276
# 4          12.413498          -7.460406             -48.200273
#
#    Middle Intermediate y  Middle Intermediate z  Middle Distal x  \
# 0              23.127060             -32.154343       -71.881516
# 1              23.157562             -32.309132       -71.756516
# 2              23.543137             -32.441475       -71.489868
# 3              25.699928             -32.364819       -70.720425
# 4              27.850657             -32.136434       -69.802015
#
#    Middle Distal y  Middle Distal z  Middle Tip x  Middle Tip y  Middle Tip z  \
# 0        13.801987       -41.613686    -81.632553      0.468155    -42.486969
# 1        13.868851       -41.830467    -81.539734      0.561050    -42.740097
# 2        14.418777       -42.123680    -81.352478      1.179886    -43.171078
# 3        17.503860       -42.311058    -81.090042      4.686867    -43.658333
# 4        20.773092       -42.612301    -80.761566      8.556666    -44.650869
#
#    Ring Proximal x  Ring Proximal y  Ring Proximal z  Ring Intermediate x  \
# 0        -5.527153         6.013611       -22.197262           -31.926264
# 1        -5.455925         6.007965       -22.216400           -31.769571
# 2        -5.306950         6.154083       -22.212486           -31.435385
# 3        -4.933538         6.672813       -22.148434           -30.562969
# 4        -4.412085         7.492304       -21.994943           -29.692863
#
#    Ring Intermediate y  Ring Intermediate z  Ring Distal x  Ring Distal y  \
# 0            17.709259           -48.901978     -52.090591      10.510880
# 1            17.721420           -48.997555     -51.912022      10.546692
# 2            18.123611           -49.061672     -51.553581      11.119614
# 3            19.782204           -48.945763     -50.844833      13.670326
# 4            21.551020           -48.641711     -50.012568      16.486781
#
#    Ring Distal z  Ring Tip x  Ring Tip y  Ring Tip z  Pinky Proximal x  \
# 0     -60.573200  -63.343086   -1.257736  -62.892952          6.396278
# 1     -60.721016  -63.176857   -1.204391  -63.069550          6.491093
# 2     -60.929134  -62.874023   -0.550339  -63.411057          6.661175
# 3     -61.024803  -62.594429    2.502068  -63.799461          6.804319
# 4     -61.132821  -62.228939    6.040899  -64.605110          7.183755
#
#    Pinky Proximal y  Pinky Proximal z  Pinky Intermediate x  \
# 0         -2.333298        -34.173100            -12.525803
# 1         -2.360947        -34.153320            -12.479721
# 2         -2.211502        -34.130566            -12.110699
# 3         -1.940689        -34.118710            -11.554880
# 4         -1.158859        -34.075986            -10.682299
#
#    Pinky Intermediate y  Pinky Intermediate z  Pinky Distal x  Pinky Distal y  \
# 0              0.970078            -58.664719      -25.007887       -1.346375
# 1              0.734467            -58.634399      -25.149132       -2.199631
# 2              1.140793            -58.730881      -24.956938       -2.408493
# 3              3.092934            -58.741636      -24.902935       -0.930557
# 4              5.521917            -58.669863      -24.354401        1.334793
#
#    Pinky Distal z  Pinky Tip x  Pinky Tip y  Pinky Tip z
# 0      -70.294624   -36.777519    -6.257996   -78.514763
# 1      -69.917137   -37.006935    -7.937576   -77.446251
# 2      -69.630417   -36.850510    -9.115829   -76.246567
# 3      -68.838737   -36.931690    -8.838234   -73.591263
# 4      -68.259288   -36.338375    -7.290212   -71.747403

# %%
df = df.drop(labels=["Leap timestamp", "timestamp diff", "emg timestamp"], axis=1)

# %%
df.head()
# Out:
#     ch1   ch2   ch3   ch4    ch5   ch6   ch7   ch8    Wrist x    Wrist y  \
# 0  20.0  26.0  45.0  62.0  270.0  38.0  23.0  24.0  44.092537 -11.826508
# 1  20.0  26.0  46.0  69.0  274.0  37.0  24.0  24.0  44.033386 -11.873871
# 2  20.0  24.0  39.0  67.0  275.0  36.0  20.0  23.0  43.889786 -12.179611
# 3  21.0  24.0  38.0  69.0  298.0  43.0  20.0  24.0  43.316656 -13.989517
# 4  21.0  24.0  36.0  69.0  261.0  38.0  19.0  23.0  42.605598 -15.925362
#
#      Wrist z  Thumb Proximal x  Thumb Proximal y  Thumb Proximal z  \
# 0  15.329117         32.816284        -17.849213         39.115044
# 1  15.461998         32.681427        -17.868637         39.218956
# 2  15.631538         32.381157        -18.243423         39.295410
# 3  15.712471         31.439707        -19.986164         39.210838
# 4  15.807536         30.223984        -22.206261         38.968119
#
#    Thumb Intermediate x  Thumb Intermediate y  Thumb Intermediate z  \
# 0             -7.700520             -4.460510             49.599419
# 1             -7.868088             -4.452667             49.540733
# 2             -8.186592             -4.713959             49.395020
# 3             -8.706076             -5.141907             49.146923
# 4             -9.576688             -6.248133             48.554169
#
#    Thumb Distal x  Thumb Distal y  Thumb Distal z  Thumb Tip x  Thumb Tip y  \
# 0      -35.444817        4.608963       56.584419   -54.457291    10.868591
# 1      -35.642456        4.626099       56.392906   -54.687771    10.879211
# 2      -35.978706        4.436554       56.077698   -55.039932    10.734818
# 3      -36.223530        4.900223       55.683292   -55.089439    11.816055
# 4      -36.892214        4.531774       54.749029   -55.574656    11.993368
#
#    Thumb Tip z  Index Proximal x  Index Proximal y  Index Proximal z  \
# 0    61.458855        -27.160671         11.812378          9.818542
# 1    61.146019        -27.173590         11.852524          9.734039
# 2    60.705765        -27.164951         11.938171          9.653145
# 3    60.228619        -26.780442         12.766251          9.667107
# 4    59.184738        -26.456961         13.383306          9.721865
#
#    Index Intermediate x  Index Intermediate y  Index Intermediate z  \
# 0            -58.868332             24.661255             -6.298439
# 1            -58.838871             24.680725             -6.482422
# 2            -58.705818             24.955734             -6.654617
# 3            -57.800222             27.029053             -6.597591
# 4            -56.977891             28.848368             -6.386009
#
#    Index Distal x  Index Distal y  Index Distal z  Index Tip x  Index Tip y  \
# 0      -77.143066       16.417236      -13.422653   -84.756599     3.553970
# 1      -77.092003       16.421097      -13.643852   -84.698669     3.554321
# 2      -76.953636       16.796005      -13.942993   -84.603577     3.968384
# 3      -76.276329       19.596748      -14.085293   -84.368996     7.078911
# 4      -75.606583       22.222661      -14.241512   -84.150408    10.099126
#
#    Index Tip z  Middle Proximal x  Middle Proximal y  Middle Proximal z  \
# 0   -15.086433         -18.418987          10.669708          -7.552521
# 1   -15.311935         -18.383682          10.688812          -7.611267
# 2   -15.711678         -18.288635          10.822479          -7.651268
# 3   -16.085609         -17.835115          11.589149          -7.597649
# 4   -16.726961         -17.330064          12.413498          -7.460406
#
#    Middle Intermediate x  Middle Intermediate y  Middle Intermediate z  \
# 0             -50.664906              23.127060             -32.154343
# 1             -50.551685              23.157562             -32.309132
# 2             -50.286522              23.543137             -32.441475
# 3             -49.262276              25.699928             -32.364819
# 4             -48.200273              27.850657             -32.136434
#
#    Middle Distal x  Middle Distal y  Middle Distal z  Middle Tip x  \
# 0       -71.881516        13.801987       -41.613686    -81.632553
# 1       -71.756516        13.868851       -41.830467    -81.539734
# 2       -71.489868        14.418777       -42.123680    -81.352478
# 3       -70.720425        17.503860       -42.311058    -81.090042
# 4       -69.802015        20.773092       -42.612301    -80.761566
#
#    Middle Tip y  Middle Tip z  Ring Proximal x  Ring Proximal y  \
# 0      0.468155    -42.486969        -5.527153         6.013611
# 1      0.561050    -42.740097        -5.455925         6.007965
# 2      1.179886    -43.171078        -5.306950         6.154083
# 3      4.686867    -43.658333        -4.933538         6.672813
# 4      8.556666    -44.650869        -4.412085         7.492304
#
#    Ring Proximal z  Ring Intermediate x  Ring Intermediate y  \
# 0       -22.197262           -31.926264            17.709259
# 1       -22.216400           -31.769571            17.721420
# 2       -22.212486           -31.435385            18.123611
# 3       -22.148434           -30.562969            19.782204
# 4       -21.994943           -29.692863            21.551020
#
#    Ring Intermediate z  Ring Distal x  Ring Distal y  Ring Distal z  \
# 0           -48.901978     -52.090591      10.510880     -60.573200
# 1           -48.997555     -51.912022      10.546692     -60.721016
# 2           -49.061672     -51.553581      11.119614     -60.929134
# 3           -48.945763     -50.844833      13.670326     -61.024803
# 4           -48.641711     -50.012568      16.486781     -61.132821
#
#    Ring Tip x  Ring Tip y  Ring Tip z  Pinky Proximal x  Pinky Proximal y  \
# 0  -63.343086   -1.257736  -62.892952          6.396278         -2.333298
# 1  -63.176857   -1.204391  -63.069550          6.491093         -2.360947
# 2  -62.874023   -0.550339  -63.411057          6.661175         -2.211502
# 3  -62.594429    2.502068  -63.799461          6.804319         -1.940689
# 4  -62.228939    6.040899  -64.605110          7.183755         -1.158859
#
#    Pinky Proximal z  Pinky Intermediate x  Pinky Intermediate y  \
# 0        -34.173100            -12.525803              0.970078
# 1        -34.153320            -12.479721              0.734467
# 2        -34.130566            -12.110699              1.140793
# 3        -34.118710            -11.554880              3.092934
# 4        -34.075986            -10.682299              5.521917
#
#    Pinky Intermediate z  Pinky Distal x  Pinky Distal y  Pinky Distal z  \
# 0            -58.664719      -25.007887       -1.346375      -70.294624
# 1            -58.634399      -25.149132       -2.199631      -69.917137
# 2            -58.730881      -24.956938       -2.408493      -69.630417
# 3            -58.741636      -24.902935       -0.930557      -68.838737
# 4            -58.669863      -24.354401        1.334793      -68.259288
#
#    Pinky Tip x  Pinky Tip y  Pinky Tip z
# 0   -36.777519    -6.257996   -78.514763
# 1   -37.006935    -7.937576   -77.446251
# 2   -36.850510    -9.115829   -76.246567
# 3   -36.931690    -8.838234   -73.591263
# 4   -36.338375    -7.290212   -71.747403

# %%
df.describe()
# Out:
#                 ch1           ch2           ch3           ch4           ch5  \
# count  90644.000000  90644.000000  90644.000000  90644.000000  90644.000000
# mean      50.343034     38.995576     70.054344    117.167623    207.296611
# std       47.437500     19.384860     34.228696     58.964764    113.647478
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       23.000000     30.000000     47.000000     83.000000    128.000000
# 50%       30.000000     35.000000     64.000000    109.000000    190.000000
# 75%       63.000000     43.000000     88.000000    140.000000    276.000000
# max      876.000000    865.000000    360.000000    968.000000    853.000000
#
#                 ch6           ch7           ch8       Wrist x       Wrist y  \
# count  90644.000000  90644.000000  90644.000000  90644.000000  90644.000000
# mean      73.619666     40.667380     46.915670     43.565293    -16.543623
# std       55.903628     37.618152     59.895361     10.922174     13.273546
# min        0.000000      0.000000      0.000000    -37.342518    -52.252678
# 25%       38.000000     22.000000     21.000000     40.156113    -26.354349
# 50%       56.000000     27.000000     25.000000     47.543688    -17.182449
# 75%       88.000000     42.000000     42.000000     50.782804     -7.449350
# max      711.000000    451.000000    869.000000     54.697679     33.876495
#
#             Wrist z  Thumb Proximal x  Thumb Proximal y  Thumb Proximal z  \
# count  90644.000000      90644.000000      90644.000000      90644.000000
# mean      16.298862         29.468180        -28.345375         37.648566
# std       11.638905         14.483940         14.712549         10.141438
# min      -36.491274        -52.192413        -61.365253        -28.681900
# 25%       10.296450         22.212662        -39.500946         33.691073
# 50%       14.045832         33.749857        -30.247257         38.894389
# 75%       19.145437         40.460614        -19.041498         42.901430
# max       50.330669         60.783119         31.743724         61.443497
#
#        Thumb Intermediate x  Thumb Intermediate y  Thumb Intermediate z  \
# count          90644.000000          90644.000000          90644.000000
# mean             -13.840866            -21.637472             36.630900
# std               12.389874             10.764520             12.256858
# min              -69.524239            -56.699036            -28.091267
# 25%              -19.770327            -29.978289             29.314059
# 50%              -11.000074            -21.859422             39.923936
# 75%               -5.712404            -13.877943             45.827902
# max               35.427771             22.056442             67.475510
#
#        Thumb Distal x  Thumb Distal y  Thumb Distal z   Thumb Tip x  \
# count    90644.000000    90644.000000    90644.000000  90644.000000
# mean       -42.301041      -16.799808       36.995007    -58.656549
# std         14.425766       16.061956       23.095537     17.945152
# min        -86.358498      -64.915352      -38.856544   -105.195740
# 25%        -49.757299      -30.745173       19.361296    -67.960465
# 50%        -41.356442      -16.732723       42.942162    -58.560487
# 75%        -35.386195       -3.132421       55.933600    -50.657806
# max         26.545908       51.961517       93.130379      3.698338
#
#         Thumb Tip y   Thumb Tip z  Index Proximal x  Index Proximal y  \
# count  90644.000000  90644.000000      90644.000000      90644.000000
# mean     -13.209089     40.826039        -29.181486         10.058690
# std       20.909914     34.431412          6.037397          5.898415
# min      -76.688690    -56.649317        -35.445456        -19.193680
# 25%      -31.913630     12.733100        -32.356494          6.108648
# 50%      -12.283810     50.368936        -30.829469         10.074291
# 75%        3.126359     69.874368        -28.480027         14.201170
# max       66.010986    115.669970          4.201332         34.305527
#
#        Index Proximal z  Index Intermediate x  Index Intermediate y  \
# count      90644.000000          90644.000000          90644.000000
# mean          10.352670            -61.115457             13.717050
# std            8.548640             13.747149             21.146828
# min          -17.321856            -76.280497            -50.524738
# 25%            9.365610            -69.960685             -1.035960
# 50%           12.895430            -64.765533             14.682308
# 75%           15.186493            -56.372974             29.942808
# max           32.182964             18.084610             68.295525
#
#        Index Intermediate z  Index Distal x  Index Distal y  Index Distal z  \
# count          90644.000000    90644.000000    90644.000000    90644.000000
# mean              -2.514473      -75.268860       10.134791       -8.669814
# std               17.789601       21.727145       32.597152       22.380069
# min              -55.320343     -100.170283      -74.389393      -77.905952
# 25%               -6.372857      -91.474951      -15.632683      -14.283288
# 50%                1.324598      -82.306496       12.042348       -3.479920
# 75%                7.490172      -65.993252       35.710094        3.725246
# max               49.044529        1.295502       91.372192       60.986764
#
#         Index Tip x   Index Tip y   Index Tip z  Middle Proximal x  \
# count  90644.000000  90644.000000  90644.000000       90644.000000
# mean     -83.331163      6.301297    -12.205750         -18.220110
# std       29.726405     39.800402     25.624801           5.185561
# min     -117.008335    -89.909307    -93.819204         -25.499319
# 25%     -106.731028    -28.751940    -18.414658         -22.202518
# 50%      -94.109327      7.552225     -6.758291         -19.549261
# 75%      -68.221990     37.172070      1.851490         -15.162064
# max        1.636757    107.884338     70.381165          15.481461
#
#        Middle Proximal y  Middle Proximal z  Middle Intermediate x  \
# count       90644.000000       90644.000000           90644.000000
# mean           13.027325          -6.553817             -52.028899
# std             5.867663           5.000612              15.437385
# min           -10.796361         -23.056222             -73.351128
# 25%             9.553713          -8.440663             -63.281076
# 50%            13.693768          -6.029035             -57.009560
# 75%            17.410385          -3.553205             -45.057343
# max            25.281733          19.313847              26.571780
#
#        Middle Intermediate y  Middle Intermediate z  Middle Distal x  \
# count           90644.000000           90644.000000     90644.000000
# mean               17.435914             -25.924223       -68.213443
# std                22.227664              15.124555        24.130516
# min               -52.542799             -69.442670      -101.449059
# 25%                 0.000000             -31.309808       -87.382077
# 50%                18.464311             -24.020995       -77.186195
# 75%                33.972722             -17.748134       -51.358368
# max                72.968979              28.387917         5.827545
#
#        Middle Distal y  Middle Distal z  Middle Tip x  Middle Tip y  \
# count     90644.000000     90644.000000  90644.000000  90644.000000
# mean         13.307036       -34.368165    -76.946679      9.214676
# std          35.705988        21.655979     32.037075     43.637358
# min         -79.983238       -97.288630   -119.927170    -98.160553
# 25%         -14.504962       -42.797934   -103.132051    -28.641613
# 50%          16.074885       -33.084525    -89.407991     11.197133
# 75%          40.609947       -22.203058    -52.507119     42.720277
# max         100.979538        39.388048      8.860561    119.518654
#
#        Middle Tip z  Ring Proximal x  Ring Proximal y  Ring Proximal z  \
# count  90644.000000     90644.000000     90644.000000     90644.000000
# mean     -38.581002        -3.241867        11.678881       -21.229939
# std       26.673263         6.644050         5.515515         4.443176
# min     -115.876521       -22.659573       -10.671036       -26.857523
# 25%      -49.241624        -8.054276         8.315304       -23.753133
# 50%      -38.254079        -4.824917        12.567495       -22.178413
# 75%      -23.477048         0.000000        15.876811       -20.116250
# max       48.626287        26.135216        26.008179        13.534844
#
#        Ring Intermediate x  Ring Intermediate y  Ring Intermediate z  \
# count         90644.000000         90644.000000         90644.000000
# mean            -32.833252            13.644964           -42.814164
# std              16.148084            20.106589            11.988360
# min             -66.056923           -48.496986           -69.666400
# 25%             -44.178363            -0.601006           -49.536027
# 50%             -38.173103            14.146770           -43.930320
# 75%             -27.222865            28.503356           -37.903389
# max              32.975393            65.293503             5.008965
#
#        Ring Distal x  Ring Distal y  Ring Distal z    Ring Tip x  \
# count   90644.000000   90644.000000   90644.000000  90644.000000
# mean      -48.038750       7.505043     -51.833341    -56.217849
# std        23.529352      32.655590      19.542013     30.190220
# min       -92.733681     -75.823303     -96.486984   -110.911503
# 25%       -66.026741     -19.050421     -63.117950    -80.572095
# 50%       -56.375172       8.397424     -54.808046    -67.063569
# 75%       -32.561109      31.760073     -41.597530    -31.363166
# max        15.593709      92.093918      24.082993     17.970547
#
#          Ring Tip y    Ring Tip z  Pinky Proximal x  Pinky Proximal y  \
# count  90644.000000  90644.000000      90644.000000      90644.000000
# mean       1.828311    -55.948080         10.538746          5.931433
# std       40.227490     25.887896          9.390970          5.928323
# min      -94.242737   -114.542386        -26.246879        -27.611140
# 25%      -33.509548    -71.205434          4.927260          1.975319
# 50%        0.978184    -60.714817          8.315020          6.425321
# 75%       31.386091    -39.667048         13.001401         10.224659
# max      110.230555     32.275167         36.535168         38.738647
#
#        Pinky Proximal z  Pinky Intermediate x  Pinky Intermediate y  \
# count      90644.000000          90644.000000          90644.000000
# mean         -34.223971             -8.153181              9.607393
# std            7.800718             17.110638             17.206984
# min          -39.584267            -54.402906            -45.858009
# 25%          -38.348851            -19.003889             -2.375984
# 50%          -37.352746            -12.985051             10.754491
# 75%          -34.446450             -0.957080             22.815386
# max           19.379990             45.803088             52.296631
#
#        Pinky Intermediate z  Pinky Distal x  Pinky Distal y  Pinky Distal z  \
# count          90644.000000    90644.000000    90644.000000    90644.000000
# mean             -55.772451      -18.174110        7.042376      -64.242108
# std               11.911438       21.288413       25.573864       17.984386
# min              -71.689339      -73.806231      -64.914497      -90.143929
# 25%              -62.780716      -32.291893      -12.539986      -76.180262
# 50%              -59.095021      -24.102576        8.135470      -70.840816
# 75%              -52.891204       -9.044863       26.058329      -58.156487
# max                0.000000       52.137440       70.787468        0.115652
#
#         Pinky Tip x   Pinky Tip y   Pinky Tip z
# count  90644.000000  90644.000000  90644.000000
# mean     -26.060563      3.162511    -69.685623
# std       25.388776     32.342320     25.136938
# min      -90.683726    -81.183350   -106.204277
# 25%      -43.839141    -23.749617    -87.691005
# 50%      -33.294212      2.693315    -79.869143
# 75%      -10.512734     26.706856    -57.595659
# max       58.048508     86.536758     15.642530

# %% [markdown]
# ### Autoencoder

# %%
raw_features = df.loc[:, 'ch1':'ch8'].values
raw_labels = df.loc[:, 'Wrist x':].values

# %%
raw_features.shape
# Out:
# (90644, 8)

# %%
raw_labels.shape
# Out:
# (90644, 63)

# %%
encoding_dim = 9

input_vec = Input(shape=(63,))
dense_0 = Dense(32, activation=None)(input_vec)
dense_1 = Dense(16, activation=None)(dense_0)
encoded = Dense(encoding_dim, activation=None)(dense_1)
dense_2 = Dense(32, activation=None, name='decoder_0')(encoded)
dense_3 = Dense(16, activation=None, name='decoder_1')(dense_2)
decoded = Dense(63, activation=None, name='decoder_output')(dense_3)

autoencoder = Model(input_vec, decoded)
encoder = Model(input_vec, encoded)

encoded_input = Input(shape=(encoding_dim,), name='encoded_input')
decode_0 = autoencoder.layers[-3](encoded_input)
decode_1 = autoencoder.layers[-2](decode_0)
decode_output = autoencoder.layers[-1](decode_1)
decoder = Model(encoded_input, decode_output, name='decoder')
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
autoencoder.compile(optimizer=optimizer, loss='mean_squared_error')
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 63)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 153
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 4,648
# Trainable params: 4,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 63)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 153
# =================================================================
# Total params: 2,729
# Trainable params: 2,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_input (InputLayer)   [(None, 9)]               0
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 1,919
# Trainable params: 1,919
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.evaluate(raw_labels, raw_labels)
# Out:
# 90457/90457 [==============================] - 2s 18us/sample - loss: 25.7911
# 25.791057894605398

# %%
ret = autoencoder.fit(raw_labels, raw_labels, batch_size=512, epochs=5, verbose=1, validation_split=0.2)
# Out:
# Train on 72365 samples, validate on 18092 samples
# Epoch 1/5
# 72365/72365 [==============================] - 1s 8us/sample - loss: 20.1048 - val_loss: 18.7581
# Epoch 2/5
# 72365/72365 [==============================] - 1s 7us/sample - loss: 20.0869 - val_loss: 18.6332
# Epoch 3/5
# 72365/72365 [==============================] - 1s 7us/sample - loss: 20.0699 - val_loss: 18.7136
# Epoch 4/5
# 72365/72365 [==============================] - 1s 7us/sample - loss: 20.0750 - val_loss: 18.5663
# Epoch 5/5
# 72365/72365 [==============================] - 1s 7us/sample - loss: 20.0549 - val_loss: 18.7204

# %%
encoded_vec = encoder.predict(raw_labels)
decoded_vec = decoder.predict(encoded_vec)

# %%
decoder.compile(optimizer='adam', loss='mse')
decoder.evaluate(encoded_vec, raw_labels)
# Out:
# 90457/90457 [==============================] - 2s 17us/sample - loss: 19.7491
# 19.749135212638006

# %%
encoded_vec.shape

# %%
decoded_vec.shape

# %%
# def reshape_data(seq_length, features, labels):
#     samples = features.shape[0] // seq_length
#     new_f = np.zeros((samples, seq_length, features.shape[1]))
#     new_l = np.zeros((samples, seq_length, labels.shape[1]))
#     j = 0
#     for i in range(0, features.shape[0], seq_length):
#         if (i + seq_length <= features.shape[0]):
#             new_f[j] = features[i:i + seq_length]
#             new_l[j] = labels[i:i + seq_length]
#         j += 1
#     return (new_f, new_l)

# %%
def overlap_reshape(seq_length, feats, labs):
    samples = feats.shape[0] - (seq_length - 1)
    new_f = np.zeros((samples, seq_length, feats.shape[1]))
    new_l = labs[seq_length - 1:]
    queue = collections.deque(feats[:seq_length])
    new_f[0] = np.array(queue)
    j = 1
    for i in range(seq_length, feats.shape[0]):
        queue.popleft()
        queue.append(feats[i])
        new_f[j] = np.array(queue)
        j += 1
    return (new_f, new_l)

# %% [markdown]
# ### Lotery LSTM (Autoencoder)

# %%
seq_length = 24
features, labels = overlap_reshape(seq_length, raw_features, encoded_vec)

# %%
# seq_length = 24
# features, labels = reshape_data(seq_length, raw_features, encoded_vec)

# %%
labels.shape
# Out:
# (90434, 9)

# %%
features.shape
# Out:
# (90621, 24, 8)

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_input (InputLayer)   [(None, 9)]               0
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 1,919
# Trainable params: 1,919
# Non-trainable params: 0
# _________________________________________________________________

# %%
#lstm layers
inputs = Input(shape=(None, 8), name="inputs")
lstm_0 = LSTM(64, return_sequences=True, name="lstm_0")(inputs)
lstm_1 = LSTM(64, return_sequences=False, name="lstm_1")(lstm_0)
lstm_out = Dense(9, activation=None, name="lstm_out")(lstm_1)

#decoder layers
decoder_0 = decoder.get_layer("decoder_0")(lstm_out)
decoder_0.trainable = False
decoder_1 = decoder.get_layer("decoder_1")(decoder_0)
decoder_1.trainable = False
decoder_output = decoder.get_layer("decoder_output")(decoder_1)
decoder_output.trainable = False

model = Model(inputs, decoder_output, name="model_v1")
# model = Model(inputs, dense, name="lstm_model")
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mse')
model.summary()
# Out:
# Model: "model_v1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, None, 8)]         0
# _________________________________________________________________
# lstm_0 (LSTM)                (None, None, 64)          18688
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# lstm_out (Dense)             (None, 9)                 585
# _________________________________________________________________
# decoder_0 (Dense)            (None, 32)                320
# _________________________________________________________________
# decoder_1 (Dense)            (None, 16)                528
# _________________________________________________________________
# decoder_output (Dense)       (None, 63)                1071
# =================================================================
# Total params: 54,216
# Trainable params: 54,216
# Non-trainable params: 0
# _________________________________________________________________

# %%
features.shape
# Out:
# (90621, 24, 8)

# %%
raw_labels[seq_length - 1:].shape
# Out:
# (90621, 63)

# %%
model.evaluate(features, raw_labels[seq_length - 1:], verbose=1)
# Out:
# 90621/90621 [==============================] - 20s 222us/sample - loss: 1669.9719
# 1669.9718925727045

# %%
model.fit(features, raw_labels[seq_length - 1:], batch_size=seq_length, epochs=2, verbose=1, validation_split=0.2);
# Out:
# Train on 72496 samples, validate on 18125 samples
# Epoch 1/2
# 72496/72496 [==============================] - 81s 1ms/sample - loss: 294.1238 - val_loss: 208.5386
# Epoch 2/2
# 72496/72496 [==============================] - 74s 1ms/sample - loss: 192.3691 - val_loss: 233.2441

# %%
model.save("saved_models/model_mixed_001.h5")

# %%
m = load_model("saved_models/overfitted_full.h5")

# %%
m.evaluate(features, raw_labels[seq_length - 1:])

# %%
preds = model.predict(features)

# %%
preds.shape

# %%
preds = preds.reshape(-1, 9)

# %%
preds.shape

# %%
raw_labels[:preds.shape[0]].shape

# %%
raw_labels[seq_length - 1:].shape

# %%
decoder.evaluate(preds, raw_labels[seq_length - 1:])

# %% [markdown]
# #### Save predictions

# %%
full_preds = decoder.predict(preds)

# %%
full_preds_df = pd.DataFrame(data=full_preds, columns=df.loc[:, 'Wrist x':].columns)

# %%
full_preds_df.to_csv("predictions/pred_001.csv", index=False)

# %% [markdown]
# ### Run a model multiple times until it hits the lottery

# %%
# %%time
eval_loss = 300
current_best = 1000
cur_model = 0

while (eval_loss > 180):
    total_epochs = 0
    inputs = Input(shape=(None, 8))
    lstm = LSTM(64, return_sequences=True)(inputs)
    lstm = LSTM(64, return_sequences=True)(lstm)
    dense = Dense(9, activation=None)(lstm)

    model = Model(inputs, dense)
    optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(optimizer=optimizer, loss='mse')

    model.evaluate(features, labels, verbose=1)

    history = model.fit(features, labels, batch_size=seq_length, epochs=1, verbose=1, validation_split=0.2)

    while (history.history['loss'][-1] - history.history['val_loss'][-1] > -100):
        history = model.fit(features, labels, batch_size=seq_length, epochs=10, verbose=1, validation_split=0.2)
        total_epochs += 10
    
    preds = model.predict(features)
    preds = preds.reshape(-1, 9)
    eval_loss = decoder.evaluate(preds, raw_labels[:preds.shape[0]])
    if (eval_loss < current_best):
        current_best = eval_loss
        model.save('saved_models/model_{}.h5'.format(round(current_best)))
    print("|||||||||||||||||||||||||||||||||||||||||||||||||")
    print("Current model ==> {}".format(cur_model))
    print("Total epochs  ==> {}".format(total_epochs))
    print("Current loss  ==> {}".format(eval_loss))
    print("Current best  ==> {}".format(current_best))
    print("|||||||||||||||||||||||||||||||||||||||||||||||||")
    cur_model += 1

# %% [markdown]
# ### Saving and loading model

# %%
from tensorflow.keras.models import load_model

model = load_model('model_200.h5')

# %%
model.save_weights('model_200_weights.h5')

# %%
model.summary()

# %%
inputs = Input(shape=(None, 8))
lstm = LSTM(256, recurrent_activation='hard_sigmoid', return_sequences=True)(inputs)
lstm = LSTM(256, recurrent_activation='hard_sigmoid', return_sequences=True)(lstm)
#lstm3 = CuDNNLSTM(256, return_sequences=True)(lstm2)
#lstm4 = CuDNNLSTM(256, return_sequences=True)(lstm3)
dense = Dense(63, activation=None)(lstm)

model = Model(inputs, dense)
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()

# %%
model.load_weights('model_200_weights.h5')

# %%
model.summary()

# %%
model.evaluate(features, labels)

# %%
model.save('model_200_v2.h5')

# %% [markdown]
# ### Lotery LSTM

# %%
inputs = Input(shape=(None, 8))
lstm = CuDNNLSTM(256, return_sequences=True)(inputs)
lstm = CuDNNLSTM(256, return_sequences=True)(lstm)
#lstm3 = CuDNNLSTM(256, return_sequences=True)(lstm2)
#lstm4 = CuDNNLSTM(256, return_sequences=True)(lstm3)
dense = Dense(63, activation=None)(lstm)

model = Model(inputs, dense)
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()

# %%
seq_length = 32

# %%
features, labels = reshape_data(seq_length, raw_features, raw_labels)

# %%
features.shape

# %%
labels.shape

# %%
model.evaluate(features, labels, verbose=1)

# %%
model.fit(features, labels, batch_size=seq_length, epochs=100, verbose=1, validation_split=0.2)

# %%
model.save("model_200.h5")

# %% [markdown]
# ### LSTM Model

# %%
seq_length = 100
features = df.loc[:, 'ch1':'ch8'].values
labels = df.loc[:, 'Wrist x':].values

# %%
features, labels = reshape_data(seq_length, features, encoded_vec)

# %%
features.shape

# %%
labels.shape

# %%
input_size = features.shape[2]
hidden_size = 256
output_size = labels.shape[2]

input_vec = Input(shape=(None, input_size))
lstm = CuDNNLSTM(hidden_size, return_sequences=True)(input_vec)
lstm = CuDNNLSTM(hidden_size, return_sequences=True)(lstm)
dense = Dense(output_size, activation=None)(lstm)

model = Model(input_vec, dense)
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()

# %%
model.fit(features, labels, batch_size=100, epochs=1000, verbose=1, validation_split=0.2)

# %% [markdown]
# ### Neural Net Model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1024, activation='relu', input_shape=(8,)))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1024, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(63, activation='relu'))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# %%
# %%time
#ret = model.fit(features, labels, epochs=3000, verbose=2)
ret = model.fit(features, labels, batch_size=256, epochs=1000, verbose=2, validation_split=0.2)
